# %%
import pandas as pd

# %%
df = pd.DataFrame({"Size":["s","m","l","xl","s","m","l","s","s","l","xl","m"]})
df.head(3)
# Out:
#   Size
# 0    s
# 1    m
# 2    l

# %%
order_data = [["s","m","l","xl"]]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=order_data)
oe.fit(df[["Size"]])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl']])

# %%
df["Size_en"]=oe.transform(df[["Size"]])

# %%
df
# Out:
#    Size  Size_en
# 0     s      0.0
# 1     m      1.0
# 2     l      2.0
# 3    xl      3.0
# 4     s      0.0
# 5     m      1.0
# 6     l      2.0
# 7     s      0.0
# 8     s      0.0
# 9     l      2.0
# 10   xl      3.0
# 11    m      1.0

# %%
ord_data1 = {"s":0,"m":1,"l":2,"xl":3}

# %%
df["Size_en_map"]=df["Size"].map(ord_data1)

# %%
df
# Out:
#    Size  Size_en  Size_en_map
# 0     s      0.0            0
# 1     m      1.0            1
# 2     l      2.0            2
# 3    xl      3.0            3
# 4     s      0.0            0
# 5     m      1.0            1
# 6     l      2.0            2
# 7     s      0.0            0
# 8     s      0.0            0
# 9     l      2.0            2
# 10   xl      3.0            3
# 11    m      1.0            1

# %%
dataset = pd.read_csv(r"E:\Raghav\scienccceee\science\data\bankloan\credit_train.csv")
dataset.head(3)
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
#
#   Years in current job Home Ownership             Purpose  Monthly Debt  \
# 0              8 years  Home Mortgage   Home Improvements       5214.74
# 1            10+ years  Home Mortgage  Debt Consolidation      33295.98
# 2              8 years       Own Home  Debt Consolidation      29200.53
#
# ...

# %%
dataset["Home Ownership"].unique()
# Out:
# array(['Home Mortgage', 'Own Home', 'Rent', 'HaveMortgage'], dtype=object)

# %%
dataset["Home Ownership"].fillna(dataset["Home Ownership"].mode()[0],inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6892\224676096.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Home Ownership"].fillna(dataset["Home Ownership"].mode()[0],inplace=True)

# %%
en_data_ord = [["Home Mortgage","Own Home","HaveMortgage","Rent"]]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oen = OrdinalEncoder(categories=en_data_ord)

# %%
oen.fit_transform(dataset[["Home Ownership"]])
# Out:
# array([[0.],
#        [0.],
#        [1.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], shape=(100514, 1))

# %%
dataset["Home Ownership"] = oen.fit_transform(dataset[["Home Ownership"]])

# %%
dataset.head(3)
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
#
#   Years in current job  Home Ownership             Purpose  Monthly Debt  \
# 0              8 years             0.0   Home Improvements       5214.74
# 1            10+ years             0.0  Debt Consolidation      33295.98
# 2              8 years             1.0  Debt Consolidation      29200.53
#
# ...

# %%
oen = OrdinalEncoder(categories=en_data_ord)
oen.fit(dataset[["Home Ownership"]])
# Out:
# OrdinalEncoder(categories=[['Home Mortgage', 'Own Home', 'HaveMortgage',
#                             'Rent']])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"E:\Raghav\scienccceee\science\data\bankloan\credit_train.csv")
dataset.head(3)
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
#
#   Years in current job Home Ownership             Purpose  Monthly Debt  \
# 0              8 years  Home Mortgage   Home Improvements       5214.74
# 1            10+ years  Home Mortgage  Debt Consolidation      33295.98
# 2              8 years       Own Home  Debt Consolidation      29200.53
#
# ...

# %%
dataset.isnull().sum()
# Out:
# Loan ID                           514
# Customer ID                       514
# Loan Status                       514
# Current Loan Amount               514
# Term                              514
# Credit Score                    19668
# Annual Income                   19668
# Years in current job             4736
# Home Ownership                    514
# Purpose                           514
# Monthly Debt                      514
# Years of Credit History           514
# Months since last delinquent    53655
# Number of Open Accounts           514
# Number of Credit Problems         514
# Current Credit Balance            514
# Maximum Open Credit               516
# Bankruptcies                      718
# Tax Liens                         524
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.drop(columns=["Months since last delinquent"],inplace =True)

# %%
dataset.shape
# Out:
# (100514, 18)

# %%
dataset.dropna(inplace=True)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.isnull().sum()
# Out:
# Loan ID                      0
# Customer ID                  0
# Loan Status                  0
# Current Loan Amount          0
# Term                         0
# Credit Score                 0
# Annual Income                0
# Years in current job         0
# Home Ownership               0
# Purpose                      0
# Monthly Debt                 0
# Years of Credit History      0
# Number of Open Accounts      0
# Number of Credit Problems    0
# Current Credit Balance       0
# Maximum Open Credit          0
# Bankruptcies                 0
# Tax Liens                    0
# dtype: int64

# %%
dataset.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         7.727100e+04  77271.000000   7.727100e+04   77271.000000
# mean          1.454562e+07   1071.759392   1.399186e+06   18755.666828
# std           3.486935e+07   1466.273187   1.094465e+06   12292.178511
# min           1.542200e+04    585.000000   7.662700e+04       0.000000
# 25%           1.931490e+05    705.000000   8.625050e+05   10478.500000
# 50%           3.269640e+05    724.000000   1.202263e+06   16475.280000
# 75%           5.530800e+05    741.000000   1.677339e+06   24302.330000
# max           1.000000e+08   7510.000000   1.655574e+08  435843.280000
#
#        Years of Credit History  Number of Open Accounts  \
# count             77271.000000             77271.000000
# mean                 17.983421                11.201020
# std                   6.796231                 5.037004
# min                   3.700000                 1.000000
# ...

# %%
sns.boxenplot(x="Monthly Debt",data=dataset)
# Out:
# <Axes: xlabel='Monthly Debt'>

# %%
sns.displot(dataset["Monthly Debt"])

# %%
dataset.shape
# Out:
# (77271, 18)

# %%
min_range = dataset["Monthly Debt"].mean() - (3*dataset["Monthly Debt"].std())
max_range = dataset["Monthly Debt"].mean() + (3*dataset["Monthly Debt"].std())

# %%
min_range,max_range
# Out:
# (np.float64(-18120.868706181103), np.float64(55632.202362792246))

# %%
new_ = dataset[dataset["Monthly Debt"]<=max_range]

# %%
sns.boxenplot(x="Monthly Debt",data=dataset)
# Out:
# <Axes: xlabel='Monthly Debt'>

# %%
z_score = (dataset["Monthly Debt"] - dataset["Monthly Debt"].mean())/(dataset["Monthly Debt"].std())

# %%
z_score>3
# Out:
# 0        False
# 2        False
# 3        False
# 5        False
# 6        False
#          ...
# 99994    False
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# Name: Monthly Debt, Length: 77271, dtype: bool

# %%
dataset["z_score"] = z_score

# %%
dataset
# Out:
#                                     Loan ID  \
# 0      14dd8831-6af5-400b-83ec-68e61888a048
# 2      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3      77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 5      89d8cb0c-e5c2-4f54-b056-48a645c543dd
# 6      273581de-85d8-4332-81a5-19b04ce68666
# ...                                     ...
# 99994  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0
# 99995  3f94c18c-ba8f-45d0-8610-88a684a410a9
# 99996  06eba04f-58fc-424a-b666-ed72aa008900
# 99997  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
# 99998  81ab928b-d1a5-4523-9a3c-271ebb01b4fb
#
#                                 Customer ID  Loan Status  Current Loan Amount  \
# 0      981165ec-3274-42f5-a3b4-d104041a9ca9   Fully Paid             445412.0
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725   Fully Paid           99999999.0
# 3      e777faab-98ae-45af-9a86-7ce5b33b1011   Fully Paid             347666.0
# 5      4ffe99d3-7f2a-44db-afc1-40943f1f9750  Charged Off             206602.0
# ...

# %%
dataset[dataset["z_score"]<3]
# Out:
#                                     Loan ID  \
# 0      14dd8831-6af5-400b-83ec-68e61888a048
# 2      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3      77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 5      89d8cb0c-e5c2-4f54-b056-48a645c543dd
# 6      273581de-85d8-4332-81a5-19b04ce68666
# ...                                     ...
# 99994  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0
# 99995  3f94c18c-ba8f-45d0-8610-88a684a410a9
# 99996  06eba04f-58fc-424a-b666-ed72aa008900
# 99997  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
# 99998  81ab928b-d1a5-4523-9a3c-271ebb01b4fb
#
#                                 Customer ID  Loan Status  Current Loan Amount  \
# 0      981165ec-3274-42f5-a3b4-d104041a9ca9   Fully Paid             445412.0
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725   Fully Paid           99999999.0
# 3      e777faab-98ae-45af-9a86-7ce5b33b1011   Fully Paid             347666.0
# 5      4ffe99d3-7f2a-44db-afc1-40943f1f9750  Charged Off             206602.0
# ...
